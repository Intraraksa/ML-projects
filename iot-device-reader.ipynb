# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('../ML-projects/temperature-readings-iot-devices/IOT-temp.csv',index_col = 'noted_date')
#data = pd.read_csv('../ML-projects/temperature-readings-iot-devices/IOT-temp.csv',date_parser='noted_date',parse_dates=True,index_col = noted_date)

# %%
data.head()
# Out:
#                                                    id  room_id/id  temp out/in
# noted_date
# 08-12-2018 09:30  __export__.temp_log_196134_bd201015  Room Admin    29     In
# 08-12-2018 09:30  __export__.temp_log_196131_7bca51bc  Room Admin    29     In
# 08-12-2018 09:29  __export__.temp_log_196127_522915e3  Room Admin    41    Out
# 08-12-2018 09:29  __export__.temp_log_196128_be0919cf  Room Admin    41    Out
# 08-12-2018 09:29  __export__.temp_log_196126_d30b72fb  Room Admin    31     In

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97606 entries, 2018-08-12 09:30:00 to 2018-07-28 07:06:00
# Data columns (total 4 columns):
# id            97606 non-null object
# room_id/id    97606 non-null object
# temp          97606 non-null int64
# out/in        97606 non-null object
# dtypes: int64(1), object(3)
# memory usage: 3.7+ MB

# %%
data.index = pd.to_datetime(data.index)

# %%
inside = data[data['out/in'] == 'In']
outside = data[data['out/in'] == 'Out']

# %%
plt.figure(figsize = (7,7))
plt.plot(inside.temp)
plt.show()
