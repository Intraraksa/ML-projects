# 2021-10-31  39.562500  39.062500  39.187500  39.375000  4.066560e+07
#
#             Adj Close
# Date
# 2016-02-29  19.198401
# 2016-03-31  22.294480
# 2016-04-30  23.363022
# 2016-05-31  24.049249
# 2016-06-30  24.992618
# ...               ...
# 2021-06-30  39.346208
# 2021-07-31  36.000741
# 2021-08-31  34.760052
# 2021-09-30  37.723809
# 2021-10-31  39.375000
#
# [69 rows x 6 columns]

# %%
close_df = ptt['Adj Close'].resample('M').mean()

# %%
plt.figure(figsize=(10,7))
# sns.set_theme(style="whitegrid")
sns.lineplot(x=close_df.index,y=close_df,palette="tab10", linewidth=2.5)

# %%
mva_ptt_df = ptt.rolling(20).mean()

# %%
fig,ax = plt.subplots(2,1,figsize=(9,8))
sns.lineplot(x=ptt.index,y=ptt['Adj Close'],palette="tab10", linewidth=2.5,ax = ax[0])
sns.lineplot(x=mva_ptt_df.index,y=mva_ptt_df['Adj Close'],palette="tab10", linewidth=2.5,ax = ax[1])

# %%
plt.figure(figsize=(10,7))
sns.lineplot(x=ptt.index,y=ptt['Adj Close'],palette="tab10", linewidth=2.5)
sns.lineplot(x=mva_ptt_df.index,y=mva_ptt_df['Adj Close'],palette="tab10")

# %% [markdown]
# ## Plot candle stick

# %%
ptt_2021 = ptt.loc['2021-5':'2021-8']

# %%
mpf.plot(ptt_2021,type='candle',mav = (15,20),volume = True)

# %% [markdown]
# ## Daily Percentage change

# %%
ptt['return'] = (ptt['Close']/ptt['Close'].shift(1))-1

# %%
ptt.head()
# Out:
#                  High        Low       Open      Close       Volume  \
# Date
# 2016-02-01  24.500000  23.000000  23.500000  24.000000  122618000.0
# 2016-02-02  23.700001  23.100000  23.700001  23.200001   65876000.0
# 2016-02-03  23.400000  22.299999  22.600000  23.400000  140363000.0
# 2016-02-04  24.299999  23.799999  24.000000  23.799999  121277000.0
# 2016-02-05  24.200001  23.700001  24.000000  24.200001   59869000.0
#
#             Adj Close    return
# Date
# 2016-02-01  18.852768       NaN
# 2016-02-02  18.224342 -0.033333
# 2016-02-03  18.381445  0.008621
# 2016-02-04  18.695662  0.017094
# 2016-02-05  19.009874  0.016807

# %%
## Mornitoring the distribution of return
sns.distplot(ptt['return'].dropna(),kde=False,bins=50)

# %% [markdown]
# # Conclusion
#
# The visualization is the simplest way to analyze the stock price in the market. This prictical is show how to create the dataframe for stock which is interesting then make Moving avarage price and creating most popular chart in the Stock market Candlestick chart to monitor movement of stock price
